# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import matplotlib.pyplot as plt


data = arff.loadarff("german_credit.arff")
data = pd.DataFrame(data[0])

# %%
data.describe()
# Out:
#                  2             5            8           11           13  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean     20.903000   3271.258000     2.973000     2.845000    35.546000
# std      12.058814   2822.736876     1.118715     1.103718    11.375469
# min       4.000000    250.000000     1.000000     1.000000    19.000000
# 25%      12.000000   1365.500000     2.000000     2.000000    27.000000
# 50%      18.000000   2319.500000     3.000000     3.000000    33.000000
# 75%      24.000000   3972.250000     4.000000     4.000000    42.000000
# max      72.000000  18424.000000     4.000000     4.000000    75.000000
#
#                 16           18
# count  1000.000000  1000.000000
# mean      1.407000     1.155000
# std       0.577654     0.362086
# min       1.000000     1.000000
# 25%       1.000000     1.000000
# 50%       1.000000     1.000000
# 75%       2.000000     1.000000
# max       4.000000     2.000000

# %%
df_generated = pd.read_csv('results/weight_cache_simple_dataset2/df_generated_data.csv')
predicted_generated = np.load('results/weight_cache_simple_dataset2/predict_generated_data.npy')
df_generated.loc[predicted_generated > 0.5].describe()
# Out:
#        Unnamed: 0          2            5          8         11         13  \
# count   99.000000  99.000000    99.000000  99.000000  99.000000  99.000000
# mean    49.616162  12.303148  3808.474377   0.674218   4.976527  31.755506
# std     29.135751   0.574871   238.096257   0.501765   0.229059   0.317138
# min      0.000000  11.054619  3359.212000  -1.245718   4.433693  31.019386
# 25%     24.500000  11.902324  3632.642350   0.409157   4.819215  31.529260
# 50%     50.000000  12.269266  3787.443400   0.740912   4.990624  31.747300
# 75%     74.500000  12.743001  3964.643200   1.064413   5.139987  31.934244
# max     99.000000  13.534406  4491.316000   1.520652   5.465912  32.487797
#
#               16  1class_colb'A12'  1class_colb'A13'  1class_colb'A14'  ...  \
# count  99.000000         99.000000         99.000000         99.000000  ...
# mean    0.864778          1.230339          0.340371          0.363864  ...
# ...

# %%
loss1 = pd.read_csv('results/weight_cache_simple_dataset1/loss.csv')
loss2 = pd.read_csv('results/weight_cache_simple_dataset2/loss.csv')

fig = plt.figure(figsize=(10, 6))
fig.patch.set_facecolor('white')
plt.title('diabetes Loss')
plt.plot(range(loss1.shape[0]), loss1['disc_loss'], color='red', label='disc_loss')
plt.plot(range(loss1.shape[0]), loss1['gen_loss'], color='blue', label='gen_loss')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
fig.patch.set_facecolor('white')
plt.title('german_credit Loss')
plt.plot(range(loss2.shape[0]), loss2['disc_loss'], color='red', label='disc_loss')
plt.plot(range(loss2.shape[0]), loss2['gen_loss'], color='blue', label='gen_loss')
plt.legend()
plt.show()

# %%
# first dataset
bb_test = np.load('results/weight_cache_complex_dataset1/black_box_test_results.npy')
min(bb_test)
# Out:
# 0.0025555555555555553

# %%
max(bb_test)
# Out:
# 0.8293359834609839

# %%
np.average(bb_test)
# Out:
# 0.3552540456494811

# %%
fig = plt.figure(figsize=(10, 6))
fig.patch.set_facecolor('white')
plt.title('RF on test set of diabetes')
plt.scatter(range(bb_test.shape[0]), bb_test, color='blue', label='bb_test')
plt.legend()
plt.show()

# %%
# second dataset
bb_test2 = np.load('results/weight_cache_complex_dataset2/black_box_test_results.npy')
min(bb_test2)
# Out:
# 0.003716630591630592

# %%
max(bb_test2)
# Out:
# 0.5303306203805974

# %%
np.average(bb_test2)
# Out:
# 0.14667277915893215

# %%
fig = plt.figure(figsize=(10, 6))
fig.patch.set_facecolor('white')
plt.title('RF on test set of german_credit')
plt.scatter(range(bb_test2.shape[0]), bb_test2, color='red', label='bb_test')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
fig.patch.set_facecolor('white')
plt.title('RF on test set')
plt.scatter(range(bb_test2.shape[0]), bb_test2, color='red', label='german_credit')
plt.scatter(range(bb_test.shape[0]), bb_test, color='blue', label='diabetes')
plt.legend()
plt.show()

# %%
df_generated_data1 = pd.read_csv('results/weight_cache_complex_dataset1/df_generated_data_for_B-C.csv')
bb_generated_results1 = np.load('results/weight_cache_complex_dataset1/black_box_generated_data_results.npy')
c_gen_1 = np.load('results/weight_cache_complex_dataset1/c_gen.npy')

# %%
df_generated_data1.iloc[:,-1].plot.hist(color='blue')
# Out:
# <AxesSubplot:ylabel='Frequency'>
